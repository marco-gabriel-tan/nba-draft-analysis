# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
players = pd.read_csv('nba_players')
player_stats = pd.read_csv('player_stats')

players = players.drop(columns=['Unnamed: 0'])
player_stats = player_stats.drop(columns=['Unnamed: 0'])

# %%
players
# Out:
#      PERSON_ID             PLAYER_NAME  SEASON  OVERALL_PICK
# 0        78331         Mychal Thompson    1978             1
# 1        76736               Phil Ford    1978             2
# 2        77984              Rick Robey    1978             3
# 3        77952  Micheal Ray Richardson    1978             4
# 4        78139            Purvis Short    1978             5
# ..         ...                     ...     ...           ...
# 375    1626161     Willie Cauley-Stein    2015             6
# 376    1626144         Emmanuel Mudiay    2015             7
# 377    1626169         Stanley Johnson    2015             8
# 378    1626163          Frank Kaminsky    2015             9
# 379    1626159         Justise Winslow    2015            10
#
# [380 rows x 4 columns]

# %%
players[(players['SEASON'] == 2003) & (players['OVERALL_PICK'] == 1)]
# Out:
#      PERSON_ID   PLAYER_NAME  SEASON  OVERALL_PICK
# 250       2544  LeBron James    2003             1

# %%
sample_player = player_stats[player_stats['PLAYER_ID'] == 2548]
sample_player
# Out:
#       PLAYER_ID SEASON_ID  LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  \
# 3458       2548   2003-04          0  1610612748               MIA
# 3459       2548   2004-05          0  1610612748               MIA
# 3460       2548   2005-06          0  1610612748               MIA
# 3461       2548   2006-07          0  1610612748               MIA
# 3462       2548   2007-08          0  1610612748               MIA
# 3463       2548   2008-09          0  1610612748               MIA
# 3464       2548   2009-10          0  1610612748               MIA
# 3465       2548   2010-11          0  1610612748               MIA
# 3466       2548   2011-12          0  1610612748               MIA
# 3467       2548   2012-13          0  1610612748               MIA
# 3468       2548   2013-14          0  1610612748               MIA
# 3469       2548   2014-15          0  1610612748               MIA
# 3470       2548   2015-16          0  1610612748               MIA
# 3471       2548   2016-17          0  1610612741               CHI
# 3472       2548   2017-18          0  1610612739               CLE
# 3473       2548   2017-18          0  1610612748               MIA
# 3474       2548   2017-18          0           0               TOT
# 3475       2548   2018-19          0  1610612748               MIA
#
#       PLAYER_AGE  GP    GS     MIN  FGM  ...  BLK  TOV   PF   PTS    PPG  \
# 3458        22.0  61  56.0  2130.0  371  ...   34  196  140   991  16.25
# 3459        23.0  77  77.0  2974.0  630  ...   82  321  230  1854  24.08
# 3460        24.0  75  75.0  2892.0  699  ...   58  268  217  2040  27.20
# 3461        25.0  51  50.0  1931.0  472  ...   62  216  117  1397  27.39
# 3462        26.0  51  49.0  1954.0  439  ...   37  224  137  1254  24.59
# 3463        27.0  79  79.0  3048.0  854  ...  106  272  178  2386  30.20
# 3464        28.0  77  77.0  2792.0  719  ...   82  252  181  2045  26.56
# 3465        29.0  76  76.0  2823.0  692  ...   87  237  197  1941  25.54
# 3466        30.0  49  49.0  1625.0  416  ...   63  129  110  1082  22.08
# 3467        31.0  69  69.0  2391.0  569  ...   56  194  140  1463  21.20
# 3468        32.0  54  53.0  1775.0  415  ...   29  161  106  1028  19.04
# 3469        33.0  62  62.0  1971.0  509  ...   21  209  105  1331  21.47
# 3470        34.0  74  73.0  2258.0  540  ...   42  203  116  1409  19.04
# 3471        35.0  60  59.0  1792.0  414  ...   41  138  112  1096  18.27
# 3472        36.0  46   3.0  1069.0  198  ...   32   92   84   513  11.15
# 3473        36.0  21   0.0   467.0  101  ...   15   48   40   252  12.00
# 3474        36.0  67   3.0  1536.0  299  ...   47  140  124   765  11.42
# 3475        37.0  72   2.0  1885.0  416  ...   38  166  118  1083  15.04
#
#        RPG   APG   SPG   BPG   TPG
# 3458  4.05  4.51  1.41  0.56  3.21
# 3459  5.16  6.75  1.57  1.06  4.17
# 3460  5.73  6.71  1.95  0.77  3.57
# 3461  4.69  7.53  2.10  1.22  4.24
# 3462  4.20  6.94  1.71  0.73  4.39
# 3463  5.04  7.46  2.19  1.34  3.44
# 3464  4.84  6.51  1.84  1.06  3.27
# 3465  6.38  4.55  1.46  1.14  3.12
# 3466  4.84  4.59  1.67  1.29  2.63
# 3467  4.99  5.10  1.86  0.81  2.81
# 3468  4.46  4.67  1.46  0.54  2.98
# 3469  3.53  4.82  1.18  0.34  3.37
# 3470  4.08  4.65  1.07  0.57  2.74
# 3471  4.50  3.80  1.43  0.68  2.30
# 3472  3.93  3.54  0.91  0.70  2.00
# 3473  3.38  3.10  0.90  0.71  2.29
# 3474  3.76  3.40  0.91  0.70  2.09
# 3475  3.96  4.18  0.82  0.53  2.31
#
# [18 rows x 33 columns]

# %%
sample_player['SEASON_ID'].nunique()
# Out:
# 16

# %%
player_stats['PPG'] = player_stats.apply(lambda x: round(x['PTS'] / x['GP'],2), axis=1)
player_stats['RPG'] = player_stats.apply(lambda x: round(x['REB'] / x['GP'], 2), axis=1)
player_stats['APG'] = player_stats.apply(lambda x: round(x['AST'] / x['GP'], 2), axis=1)
player_stats['SPG'] = player_stats.apply(lambda x: round(x['STL'] / x['GP'], 2), axis=1)
player_stats['BPG'] = player_stats.apply(lambda x: round(x['BLK'] / x['GP'], 2), axis=1)
player_stats['TPG'] = player_stats.apply(lambda x: round(x['TOV'] / x['GP'], 2), axis=1)

# %%
player_id = 2544

plt.plot(player_stats['PLAYER_AGE'][player_stats['PLAYER_ID'] == player_id], player_stats['PPG'][player_stats['PLAYER_ID']==player_id])
plt.grid()
plt.xlabel('Age')
plt.ylabel('PPG')
_ = plt.show()

# %%
player_stats_no_tot = player_stats[player_stats['TEAM_ABBREVIATION'] != 'TOT']

# %%
player_stats_no_tot
# Out:
#       PLAYER_ID SEASON_ID  LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0         78331   1978-79          0  1610612757               POR
# 1         78331   1980-81          0  1610612757               POR
# 2         78331   1981-82          0  1610612757               POR
# 3         78331   1982-83          0  1610612757               POR
# 4         78331   1983-84          0  1610612757               POR
# ...         ...       ...        ...         ...               ...
# 5102    1626159   2019-20          0  1610612748               MIA
# 5103    1626159   2020-21          0  1610612763               MEM
# 5104    1626159   2021-22          0  1610612746               LAC
# 5105    1626159   2021-22          0  1610612757               POR
# 5107    1626159   2022-23          0  1610612757               POR
#
#       PLAYER_AGE  GP    GS     MIN  FGM  ...  BLK  TOV   PF   PTS    PPG  \
# 0           24.0  73   NaN  2144.0  460  ...  134  205  270  1074  14.71
# 1           26.0  79   NaN  2790.0  569  ...  170  241  260  1345  17.03
# 2           27.0  79  78.0  3129.0  681  ...  107  245  233  1642  20.78
# 3           28.0  80  80.0  3017.0  505  ...  110  281  213  1259  15.74
# 4           29.0  79  74.0  2648.0  487  ...  108  235  237  1240  15.70
# ...          ...  ..   ...     ...  ...  ...  ...  ...  ...   ...    ...
# 5102        24.0  11   5.0   352.0   50  ...    5   24   38   124  11.27
# 5103        25.0  26   1.0   507.0   74  ...   12   37   47   178   6.85
# 5104        26.0  37   1.0   480.0   63  ...   18   37   46   156   4.22
# 5105        26.0  11  10.0   295.0   47  ...    7   12   21   118  10.73
# 5107        27.0  29  11.0   776.0   81  ...   11   43   89   196   6.76
#
#         RPG   APG   SPG   BPG   TPG
# 0      8.27  2.41  0.92  1.84  2.81
# 1      8.68  3.59  0.78  2.15  3.05
# 2     11.66  4.04  0.87  1.35  3.10
# 3      9.41  4.75  0.85  1.38  3.51
# 4      8.71  3.90  1.06  1.37  2.97
# ...     ...   ...   ...   ...   ...
# 5102   6.64  4.00  0.64  0.45  2.18
# 5103   4.54  1.92  0.58  0.46  1.42
# 5104   3.59  1.41  0.57  0.49  1.00
# 5105   6.27  2.91  1.27  0.64  1.09
# 5107   5.00  3.38  1.03  0.38  1.48
#
# [4706 rows x 33 columns]
